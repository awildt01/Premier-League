# %% [markdown]
# <a href="https://colab.research.google.com/github/awildt01/Premier-League/blob/main/churn_dev1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://elevatex.de/de/blog/it/churn-modeling-eine-detaillierte-schritt-fur-schritt-anleitung-in-python/
#
# https://www.kaggle.com/code/bhartiprasad17/customer-churn-prediction
#
#
# https://www.kaggle.com/code/bandiatindra/telecom-churn-prediction

# %% [markdown]
# # Churn Prediction
#
# In einer allgemeineren Definition ist *Churn* eine Kennzahl, die die Anzahl der Kunden angibt, die  in einem bestimmten Zeitraum kündigen . Um die Abwanderung zu berechnen, müssen Sie lediglich die Anzahl der Kunden addieren, die Ihr Produkt/Ihre Dienstleistung im analysierten Zeitraum gekündigt haben.
#
# //
# <p align=center>
# <img src="https://vanessamiranda.github.io/images/Customerchurn/customerchurn.jpg" width="60%"></p>
#
#
#
# Die Abwanderungsrate wird im Allgemeinen über einen bestimmten Zeitraum berechnet, sei es jährlich, halbjährlich oder monatlich. Beispiel: Wenn jeden Monat einer von 20 Kunden Ihr Produkt kündigt, bedeutet dies, dass die Abwanderungsrate für Ihr Produkt 5 % beträgt.
# Sie können auch die Abwanderungsrate, die den Prozentsatz der Konten darstellt, die gekündigt werden, im Vergleich zum aktiven Kundenstamm wie folgt berechnen:
#
# **Abwanderungsrate : Gesamtzahl gekündigter Kunden / Gesamtzahl aktiver Kunden im letzten Monat**
#
# Die Kundenabwanderung wirkt sich auf die Rentabilität aus, besonders in Branchen, in denen die Einnahmen stark von Abonnements abhängig sind (z. B. Banken, Telefon- und Internetdienstanbieter, Pay-TV-Unternehmen, Versicherungsunternehmen usw.). Es wird geschätzt, dass die Gewinnung eines neuen Kunden bis zu fünfmal mehr kosten kann, als die Bindung eines bestehenden Kunden. Daher ist die Kundenabwanderungsanalyse unerlässlich für ein Unternehmen. Das Ziel dieses Projektes ist es, die Churn für eine Unternehmen zu verstehen und vorherzusagen.
#
# Das Ziel der Churn Prediction ist es, diese abwanderungsgefährdeten Kunden zu identifizieren, bevor sie das Unternehmen verlassen, und präventive Maßnahmen zu ergreifen, um sie zu halten. Dies kann bedeutsam sein, da die Neukundengewinnung oft teurer ist als die Bindung bestehender Kunden.

# %% [markdown]
# ## Datenbeschaffung
#
# Das Datenmodul stammenn aus der DataIBM Business Analytics und ist ein Beispiel als Telco Customer Churn. Die Kundenabwanderungsdaten von Telekommunikationsunternehmen enthalten Informationen über ein fiktives Telekommunikationsunternehmen, das im dritten Quartal 7043 Kunden in Kalifornien Telefon- und Internetdienste zu Hause bereitgestellt hat. Es zeigt an, welche Kunden ihren Service verlassen, geblieben oder sich für ihn angemeldet haben. Für jeden Kunden sind mehrere wichtige Daten sowie ein Zufriedenheitswert, ein Abwanderungswert und ein CLTV-Index (Customer Lifetime Value) enthalten.
#
# * *Website [neste link](https://community.ibm.com/community/user/businessanalytics/blogs/steven-macko/2019/07/11/telco-customer-churn-1113).*

# %% [markdown]
# ### Die Herausforderung der Analyse
#
# Eine der Haupt Herausforderungen besteht darin, genaue Vorhersagen darüber zu treffen, welche Kunden wahrscheinlich abwandern werden. Dies erfordert eine gründliche Analyse einer Vielzahl von Daten, die das Kundenverhalten und die Interaktionen mit dem Unternehmen beschreiben. Jedoch können Datenqualität und -quantität eine Herausforderung darstellen, da Unternehmen möglicherweise nicht über ausreichende oder qualitativ hochwertige Daten verfügen, um präzise Vorhersagen zu treffen.
#
# Ein weiteres Problem ist die Bewältigung von unbalancierten Daten, da die Anzahl der abwandernden Kunden oft viel kleiner ist als die Anzahl der nicht abwandernden Kunden. Dies kann zu Verzerrungen führen und die Leistung des Modells beeinträchtigen. Es ist wichtig, Techniken zur Bewältigung von unbalancierten Daten anzuwenden, um genaue Vorhersagen zu gewährleisten.
#
# Zusätzlich können komplexe Kundenverhaltensmuster und Wechselwirkungen zwischen verschiedenen Merkmalen eine Herausforderung darstellen. Das Identifizieren relevanter Merkmale und das Verständnis ihrer Auswirkungen auf das Churn-Verhalten erfordert oft Fachkenntnisse und fortgeschrittene Analysetechniken.
#
# Die Vorhersagegenauigkeit ist ein weiteres Anliegen, da Vorhersagemodelle oft Overfitting oder Underfitting zeigen können. Overfitting tritt auf, wenn das Modell zu stark an die Trainingsdaten angepasst ist und nicht in der Lage ist, auf neuen Daten gut zu generalisieren. Underfitting hingegen tritt auf, wenn das Modell zu einfach ist und nicht in der Lage ist, die zugrunde liegenden Muster der Daten zu erfassen.
#
# Datenschutz und Datenschutz sind ebenfalls wichtige Aspekte bei der Churn-Analyse, da sie den Umgang mit sensiblen Kundeninformationen betreffen. Es ist entscheidend sicherzustellen, dass alle Datenschutzbestimmungen eingehalten werden und dass Kundeninformationen sicher und vertraulich behandelt werden.
#
# Trotz dieser Herausforderungen bietet die Churn-Analyse Unternehmen die Möglichkeit, Kundenbeziehungen zu stärken und langfristige Kundenloyalität aufzubauen. Durch den Einsatz fortgeschrittener Analysetechniken und die Berücksichtigung von Datenschutzbestimmungen können Unternehmen präzise Vorhersagen treffen und wirksame Strategien zur Kundenbindung entwickeln.

# %% [markdown]
# ### Wörterbuch der Variablen
# * *dicionário de variáveis.*
#     * *Die Beschreibung der Spaltennamen [neste link](https://community.ibm.com/community/user/businessanalytics/blogs/steven-macko/2019/07/11/telco-customer-churn-1113).*
#
#
# **customerID** **->** Customer ID.
#
# **gender** **->** Whether the customer is a male or a female.
#
# **SeniorCitizen** **->** Indicates if the customer is 65 (1, 0).
#
# **Partner** **->** Whether the customer has a partner or not (Yes, No).
#
# **Dependents** **->** Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
#
# **tenure** **->** Number of months the customer has stayed with the company
#
# **PhoneService**  **->** Whether the customer has a phone service or not (Yes, No).
#
# **MultipleLines** **->** Indicates if the customer subscribes to multiple telephone lines with the company: (Yes, No, No phone service).
#
# **InternetService**  **->** Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
#
# **OnlineSecurity**  **->** Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No.
#
# **OnlineBackup**  **->** Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No.
#
# **DeviceProtection**  **->** Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company:Yes, No.
#
# **TechSupport**  **->** Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
#
# **StreamingTV**  **->**  Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# **StreamingMovies**  **->** Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# **Contract**  **->** Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
#
# **PaperlessBilling**  **->** Indicates if the customer has chosen paperless billing: Yes, No.
#
# **PaymentMethod**  **->** Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check.
#
# **MonthlyCharges**  **->** Indicates the customer’s current total monthly charge for all their services from the company.
#
# **TotalCharges**  **->** Indicates the customer’s total charges, calculated to the end of the quarter specified above.
#
# **Churn**  **->** Churn

# %%
# importar os pacotes necessários
# !pip install bar_chart_race -q
# !pip install plotly

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import missingno as msno

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots


import bokeh.io
import bokeh.plotting
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure, show
from bokeh.transform import factor_cmap
from bokeh.models import Range1d
from bokeh.models import LabelSet

# para não limitar a visualização do número de colunas
pd.set_option('display.max_columns', None)

# renderers
import plotly.io as pio
pio.renderers.default = 'colab'

sns.set_style()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# importar os dados
DATA_PATH = "https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/WA_Fn-UseC_-Telco-Customer-Churn.csv"
df = pd.read_csv(DATA_PATH)

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
print("Linhas:\t\t{}".format(df.shape[0]))
print("Colunas:\t{}".format(df.shape[1]))
# Out:
# Linhas:		7043
# Colunas:	21

# %% [markdown]
# #  Data Manipulation
#
# Um dieses Projekt zu beginnen, werde ich die Integrität und die Nutzbarkeit des Datensatzes überprüfen.
# Dazu werde ich die Anzahl der fehlenden Daten, die Namen der Spalten, die Variablentypen pro Spalte und die eindeutigen Werte pro Spalte ausdrucken. Letzteres wird insbesondere bei der Identifizierung potenziell kategorischer Variablen helfen.

# %%
print("fehlenden Daten (total):\t{}\n".format(df.isnull().sum().values.sum()))
print(df.isnull().sum() / df.shape[0])
print("\nName features:\n{}\n".format(df.columns.values))
print("Eindeutigen Werte (pro Spalte):\n{}\n".format(df.nunique()))
print("Variablentypen (pro Spalte)\n{}".format(df.dtypes))
# Out:
# fehlenden Daten (total):	0
#
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64
#
# Name features:
# ['customerID' 'gender' 'SeniorCitizen' 'Partner' 'Dependents' 'tenure'
#  'PhoneService' 'MultipleLines' 'InternetService' 'OnlineSecurity'
#  'OnlineBackup' 'DeviceProtection' 'TechSupport' 'StreamingTV'
#  'StreamingMovies' 'Contract' 'PaperlessBilling' 'PaymentMethod'
#  'MonthlyCharges' 'TotalCharges' 'Churn']
#
# Eindeutigen Werte (pro Spalte):
# customerID          7043
# ...

# %% [markdown]
# Hier sind einige wichtige Beobachtungen, die in dieser frühen Phase der Bewusstseinsbildung gemacht wurden::
#
# * Die Spalte costumerID trägt keine Informationen bei, da es sich um einen eindeutigen Identifikator für jeden Kunden handelt.
# * Die Zielvariable befindet sich in der Spalte Churn, die die Churn-Situation angibt.
# * Die Spalte `TotalCharges` sollte ein `float` sein, ist jedoch als `string`.
#     * Wie wir später sehen werden, obwohl wir keine fehlenden Werte festgestellt haben, gibt es einige Strings, die fehlende Werte darstellen.
# * Mehrere Merkmale müssen in numerische Werte codiert werden.
#     * Es gibt mehrere binäre Merkmale, einschließlich unserer Zielvariablen, oder mit mehreren Werten, von denen jeder eine Kategorie darstellt.
#
# * Die Spalten `MultipleLines`,`OnlineSecurity`,`OnlineBackup`,`DeviceProtection`,`TechSupport`,`StreamingTV`und  `StreamingMovies`sind kategoriale Merkmale mit den Werten ['No', 'Yes', 'No internet service']. Hier wird vermutet, dass ein Fehler bei der Eintragung in den Datensatz vorliegt. 'No' und 'No internet service' haben die gleiche Bedeutung.

# %%
# Die Spalten OnlineSecurity,	OnlineBackup,	DeviceProtection,	TechSupport,	StreamingTV	StreamingMovies, sind Categorische Merkmale mit dem Werte ['No' 'Yes' 'No internet service'].
# Hier wird vermutet ein Fehler bei der Eintragung in den Datensatz. 'No' und 'No internet service' haben einglische den gleichen Beteutung.

df.sample(50,random_state=49)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3122  8395-ETZKQ    Male              1     Yes        Yes      68
# 3972  5382-TEMLV    Male              0      No         No      45
# 3372  2883-ILGWO    Male              1      No         No      57
# 5266  2027-DNKIV    Male              0     Yes        Yes      37
# 5922  5965-GGPRW    Male              0     Yes        Yes      72
# 6831  9451-LPGOO    Male              0      No         No       7
# 4465  3606-SBKRY    Male              0      No         No      31
# 4290  7734-DBOAI  Female              0     Yes        Yes       1
# 617   7134-MJPDY  Female              1      No         No      66
# 6747  5245-VDBUR  Female              0     Yes         No      52
# 1215  9897-KXHCM  Female              0     Yes        Yes       3
# 6168  2868-MZAGQ    Male              0      No         No       1
# 1964  2430-RRYUW    Male              0      No         No      66
# ...

# %%
df.sample(50,random_state=49)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3122  8395-ETZKQ    Male              1     Yes        Yes      68
# 3972  5382-TEMLV    Male              0      No         No      45
# 3372  2883-ILGWO    Male              1      No         No      57
# 5266  2027-DNKIV    Male              0     Yes        Yes      37
# 5922  5965-GGPRW    Male              0     Yes        Yes      72
# 6831  9451-LPGOO    Male              0      No         No       7
# 4465  3606-SBKRY    Male              0      No         No      31
# 4290  7734-DBOAI  Female              0     Yes        Yes       1
# 617   7134-MJPDY  Female              1      No         No      66
# 6747  5245-VDBUR  Female              0     Yes         No      52
# 1215  9897-KXHCM  Female              0     Yes        Yes       3
# 6168  2868-MZAGQ    Male              0      No         No       1
# 1964  2430-RRYUW    Male              0      No         No      66
# ...

# %%
# Überfrüfung von fehlende Werte
msno.bar(df);

# %%
# Duplikatsprüfung
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Se­lek­ti­on kategorialer und numerischer Merkmale
#
# -  **SENIORCITIZEN** ein kategorischer variabler Typ ist und numerisch angezeigt wird.
# - Daher müssen wir ihn zunächst in eine kategoriale Funktion umwandeln.
# - **TOTALCHARGES** wird als kategorischer Typ angezeigt, aber ist ein numerischer variabler Typ.

# %%
# Allen Spalten von der Typ object float und int werden in zwei Listen eingesammelt.
# Die Funktion  summarize_cat gibt die eindeutigen Werte von jeden Spalten zurück, je nach Datentyp in einem Dataframe
# TOTALCHARGES wird als kategorische variablen Typ angezeigt, aber ist ein numerischer Wert.
# Daher müssen wir ihn zunächst in eine numerische umwandeln.

# drop customerID
#df.drop("customerID", axis=1, inplace=True)

# select Spalten von Type object
categorical_features = df.select_dtypes(include=[object]).columns

# TotalCharges wird  als numerische Merkmal behandeln, also wird von Katerorische Merkmalen entfernt und SeniorCitizen eingefügt
categorical_features= list(categorical_features.difference(['TotalCharges'])) + ['SeniorCitizen']

#SENIORCITIZEN wird  als kategoriales Merkmal behandeln, so das von numerischen Merkmalen entfernt ist und TotalCharge eingefügt.
numerical_features = list(df.select_dtypes(include=[np.float64,np.int64]).columns.difference(['SeniorCitizen'])) + ['TotalCharges']

# %%
#  Funktion zum Zusammenfassen kategorialer und Numerische Daten durch Auflisten eindeutiger Werte für jede Kategorie in einem Datenrahmen
def summarize_cat(data,categorical_features):
    results=[]

    for column in data[categorical_features]:
        # eindeutigen Werte der Spalte
        members = data[column].unique().tolist()
        # Hängen Sie den Spaltennamen und seine eindeutigen Werte an die liste an
        results.append([column, members])

    return pd.DataFrame(results, columns=['Column Name', 'Members'])

# Das Datenset wurde numerisch und kategorisch eingeteilt. So hat man einen besseren Überblick, wie die Daten verteilt sind.

# %% [markdown]
# ### Katerorische Merkmalen

# %%
summarize_cat(df,categorical_features)
# Out:
#          Column Name                                            Members
# 0              Churn                                          [No, Yes]
# 1           Contract               [Month-to-month, One year, Two year]
# 2         Dependents                                          [No, Yes]
# 3   DeviceProtection                     [No, Yes, No internet service]
# 4    InternetService                             [DSL, Fiber optic, No]
# 5      MultipleLines                        [No phone service, No, Yes]
# 6       OnlineBackup                     [Yes, No, No internet service]
# 7     OnlineSecurity                     [No, Yes, No internet service]
# 8   PaperlessBilling                                          [Yes, No]
# 9            Partner                                          [Yes, No]
# 10     PaymentMethod  [Electronic check, Mailed check, Bank transfer...
# 11      PhoneService                                          [No, Yes]
# ...

# %% [markdown]
# ### Numerische Merkmale

# %%
summarize_cat(df,numerical_features)
# Out:
#       Column Name                                            Members
# 0  MonthlyCharges  [29.85, 56.95, 53.85, 42.3, 70.7, 99.65, 89.1,...
# 1          tenure  [1, 34, 2, 45, 8, 22, 10, 28, 62, 13, 16, 58, ...
# 2    TotalCharges  [29.85, 1889.5, 108.15, 1840.75, 151.65, 820.5...

# %% [markdown]
# # Spalten transformation
# Die Spalten **OnlineSecurity,	OnlineBackup,	DeviceProtection,	TechSupport,**	**StreamingTV,	StreamingMovies**, sind Categorische Merkmale mit dem Werte **['No' 'Yes' 'No internet service','No phone service']**. Hier wird vermutet ein dass Fehler bei der Eintragung in den Datensatz liegt. 'No', 'No phone service' und 'No internet service' haben den gleichen Beteutung.

# %%
# Die Funktion transform wandeltet die Werte 'No internet service','No phone service' in No
def transform_no (wert):
  if (wert == 'No phone service' or wert=='No internet service' or wert=='No'):
    return 'No'

  else:
    return'Yes'

df['MultipleLines'] = df['MultipleLines'].map(transform_no)
df['OnlineSecurity'] = df['OnlineSecurity'].map(transform_no)
df['OnlineBackup'] = df['OnlineBackup'].map(transform_no)
df['DeviceProtection'] = df['DeviceProtection'].map(transform_no)
df['TechSupport'] = df['TechSupport'].map(transform_no)
df['StreamingTV'] = df['StreamingTV'].map(transform_no)
df['StreamingMovies'] = df['StreamingMovies'].map(transform_no)

# %% [markdown]
# Die Spalte **TotalCharges** könnte nicht zum mumerische Spalte ungewandelt werden.
# - df["TotalCharges"].astype('float32')
# -ValueError: could not convert string to float: ' '
#
# info: https://saturncloud.io/blog/how-to-handle-the-pandas-valueerror-could-not-convert-string-to-float/

# %%
# Indexposition von ValueError: could not convert string to float: ' ' ermittelten.Split gibt 0 zurück bei leer Zeichen
l1 = [len(i.split()) for i in df['TotalCharges']]
l2 = [i for i in range(len(l1)) if l1[i] != 1]
print('Index Positionen mit empty spaces : ',l2)

# Konvertiert die Spalte 'TOTALCHARGES' in numerisch, entfernt Leerzeichen, ersetzt Fehler durch NaN -> Datenbereinigung.
df.TotalCharges = pd.to_numeric(df.TotalCharges.str.strip(), errors='coerce',)
# Out:
# Index Positionen mit empty spaces :  [488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754]

# %%
# Kopie von dataframe
df_clean = df.copy()

# %%
# Die Spalte hat jetzt 11 Werte mit NaN
#print("Total NAN Werte'TotalCharges'(vorher):\t{}\n".format(df["TotalCharges"].isnull().sum()))
display("Total NAN Werte'TotalCharges'(vorher):{}".format(df["TotalCharges"].isnull().sum()))

# Füllen die NaN Werte mit dem Median
TotalChargesMedian = df_clean.TotalCharges.median()
df_clean["TotalCharges"].fillna(TotalChargesMedian, inplace=True)

# Spalte TotalCharges ist beregniet.
print("Total NAN Werte'TotalCharges'(nachher):\t{}\n".format(df_clean["TotalCharges"].isnull().sum()))
# Out:
# "Total NAN Werte'TotalCharges'(vorher):11"
# Total NAN Werte'TotalCharges'(nachher):	0

# %% [markdown]
# - Beim Konvertieren der TotalCharges in Float ist ein Fehler mit der Meldung aufgetreten, dass die Zeichenfolge nicht in Float konvertiert werden konnte.
# - Diese Meldung wurde angezeigt, weil an den oben angezeigten Indexpositionen der Spalte „TotalCharges“ leere Zeichenfolgen vorhanden waren.
# - Da diese Elemente als Zeichenfolgen definiert wurden, wurden sie nicht als Nullwerte angezeigt und daher wurde in der missingno für fehlende Werte nichts angezeigt.
# - Beispiel: a = ' '
# - Daher teilen wir die einzelnen Elemente von TotalCharges auf und speichern die Indexwerte der Elemente, deren geteilte Stringlänge ungleich 1 ist.
# - Dadurch wird die Spalte mit dem Medianwert gefüllt, und schließlich wird die gesamte Spalte mithilfe der Funktion to_numeric in Float umgewandelt.
# - Wir streichen auch die Spalte „customerID“!
# Unterteilen wir die Features in numerische und kategoriale Features.
# Wir werden auch die Label-Codierungstransformation für kategoriale Features durchführen.

# %%
# datatype für TOTALCHARGES ist jetzt richtig
df_clean.TotalCharges.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: TotalCharges
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   float64
# dtypes: float64(1)
# memory usage: 55.1 KB

# %% [markdown]
# # Explorative Datenanalyse

# %% [markdown]
# Obwohl dieser Datensatz größtenteils aus binären oder kategorialen Variablen besteht, lässt sich unten mit der Methode „describe“ erkennen, dass es keine Hinweise auf das Vorhandensein von Ausreißern gibt.

# %%
df_clean.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2281.916928
# std         0.368612    24.559481       30.090047   2265.270398
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    402.225000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# Beachten Sie bei der Analyse des Boxplots für die Spalten „MonthlyCharges“ und „TotalCharges“, wie die Verteilung der Werte diese Hypothese untermauert. Der Standardschwellenwert hat keinen Plot außerhalb der oberen und unteren Grenzen erkannt.

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

y0 = df_clean['MonthlyCharges']
y1 = df_clean['TotalCharges']  # shift mean

fig = make_subplots(rows=1, cols=2)

fig.add_trace(
    go.Box(y=y0,name='MonthlyCharges', marker_color = '#0068B5',opacity= 0.9),
    row=1, col=1
)

fig.add_trace(
    go.Box(y=y1, name='TotalCharges',marker_color='#0068B5',opacity= 0.9),
    row=1, col=2
)

fig.update_layout(height=600, width=800, title_text="MonthlyCharges vs TotalCharges",template='plotly_white',showlegend = False,)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Wie ist die Verteilung der Zielvariable?**
#
# Bei der Schätzung von Machine Learning Modellen tritt häufig das Problem der Klassen-Imbalance auf. Das bedeutet, dass die Zielvariable (Target) nicht gleich, sondern ungleichmäßig verteilt ist. Meist ist die positive Klasse sehr klein, während die negative Klasse sehr groß ist, angenommen eine binäre Target-Klasse.
#
# Die Nein-Klasse kommt viel häufiger vor als die Ja-Klasse. Dies wird in der Phase der Modellerstellung für maschinelles Lernen berücksichtigt.

# %%
# Wie viele Personen haben storniert und wie viele haben nicht storniert
display(df_clean["Churn"].value_counts())

# in Prozent
display(df_clean["Churn"].value_counts(normalize=True))
display(df_clean["Churn"].value_counts(normalize=True).map("{:.1%}".format))

df_clean["Churn"].value_counts(normalize=True).map("{:.1%}".format)

a = df_clean["Churn"].value_counts(normalize=True)
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64
# Churn
# No     73.5%
# Yes    26.5%
# Name: proportion, dtype: object

# %%
# Grafik
churn = df_clean["Churn"].value_counts(normalize=True)
#rate_list = df_clean["Churn"].value_counts(normalize=True)
rate_list = df_clean["Churn"].value_counts(normalize=True).map("{:.1%}".format)
#rate =[10,50]
#rate = a.tolist()
# rate = []
# for i in rate_list:
#    x = i * 100
#    rate.append(x)



# Erzeugen von der Balkendiagramm
data =[go.Bar(x =['No','Yes'], y= churn , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.2}
                        }, name='Churn' ,text = rate_list,
      textposition='outside',opacity= 0.9 )]


# Layout mit Titleposition
configuracoes_layout = go.Layout(title={
        'text': "Churn Rate<br><sup></sup>",
        'y':0.9,
        'x':0.4,
        'xanchor': 'center',
        'yanchor': 'top'},
        yaxis={'title':' '},
        xaxis={'title': ' '},
        showlegend = False,
        hovermode = 'closest',
        titlefont = dict(size=20),
        template='plotly_white',
        )

# Erzeugen von der Figure
fig = go.Figure(data=data,layout=configuracoes_layout, layout_yaxis = {'title': ' ',
                         'visible': False,
                       'showticklabels': False})

# Formatierung von der Porzente auf die Balken.
#fig.update_traces(texttemplate='%{text:.2f}%', textposition='outside',)

# Size der Figur
fig.update_layout(
    height=500,
    width = 500,
    #title_text=' '
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

y0 = df_clean['SeniorCitizen']
y1 = df_clean['gender']  # shift mean

display("Total")
display(df_clean["gender"].value_counts())
display('------------------------------- ')
display(df_clean["SeniorCitizen"].value_counts())
display('-------------------------------- ')
display(df_clean["Dependents"].value_counts())
display('-------------------------------- ')
display(df_clean["Partner"].value_counts())


gender = df_clean["gender"].value_counts()
seniorCitizen = df_clean["SeniorCitizen"].value_counts()
dependents = df_clean["Dependents"].value_counts()
partner= df_clean["Partner"].value_counts()
# Out:
# 'Total'
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
# '------------------------------- '
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64
# '-------------------------------- '
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
# '-------------------------------- '
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %% [markdown]
# # Umbelanciert Klasse

# %%
fig = make_subplots(rows=2, cols=2, subplot_titles=("Gender", "SeniorCitizen","Dependents","Partner"))

fig.add_trace(
    go.Bar(x =['Male','Female'], y= gender , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["gender"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ),row=1, col=1)


fig.add_trace(
     go.Bar(x =['No','Yes'], y= dependents, marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["Dependents"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=1, col=2
     )


fig.add_trace(
     go.Bar(x =['No','Yes'], y= seniorCitizen , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["SeniorCitizen"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=2, col=1
     )

fig.add_trace(
     go.Bar(x =['No','Yes'], y= partner , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["Partner"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=2, col=2
     )


fig.update_yaxes(visible=False, showticklabels=False)
#fig.update_yaxes(title_font=dict(size=18, family='Courier', color='crimson'))
fig.update_layout(height=1000, width=1200,title_text=" ",template='plotly_white',showlegend = False, )

# fig = go.Figure(data=data,layout=configuracoes_layout, layout_yaxis = {'title': ' ',
#                          'visible': False,
#                        'showticklabels': False})

fig.show()

# # Erzeugen von der Balkendiagramm
# data =[go.Bar(x =churn, y= rate , marker = {'color': '#0068B5',
#                          'line': {'color': '#334',
#                                   'width': 0.7}
#                         }, name='Churn' ,text = rate,
#       textposition='outside',opacity= 0.9 )]
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
a = len('hallo'.split())
a
# Out:
# 1

# %%
df_clean.head()

# OnlineSecurity

# PhoneService	MultipleLines	InternetService	OnlineBackup	DeviceProtection	TechSupport	StreamingTV	StreamingMovies


# InternetService	 Contract	PaperlessBilling	PaymentMethod
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
# 1            No             DSL            Yes           No              Yes
# 2            No             DSL            Yes          Yes               No
# 3            No             DSL            Yes           No              Yes
# 4            No     Fiber optic             No           No               No
#
# ...

# %%
y0 = df_clean['SeniorCitizen']
y1 = df_clean['gender']  # shift mean

display("Total")
display(df_clean["PhoneService"].value_counts())
display('------------------------------- ')
display(df_clean["MultipleLines"].value_counts())
display('-------------------------------- ')
display(df_clean["OnlineSecurity"].value_counts())
display('-------------------------------- ')
display(df_clean["DeviceProtection"].value_counts())
display('-------------------------------- ')
display(df_clean["StreamingTV"].value_counts())
display('-------------------------------- ')
display(df_clean["StreamingMovies"].value_counts())



PhoneService = df_clean["PhoneService"].value_counts()
MultipleLines= df_clean["MultipleLines"].value_counts()
OnlineSecurity = df_clean["OnlineSecurity"].value_counts()
DeviceProtection = df_clean["DeviceProtection"].value_counts()
StreamingTV = df_clean["StreamingTV"].value_counts()
StreamingMovies = df_clean["StreamingMovies"].value_counts()
# Out:
# 'Total'
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
# '------------------------------- '
# MultipleLines
# No     4072
# Yes    2971
# Name: count, dtype: int64
# '-------------------------------- '
# OnlineSecurity
# No     5024
# Yes    2019
# Name: count, dtype: int64
# '-------------------------------- '
# DeviceProtection
# No     4621
# Yes    2422
# Name: count, dtype: int64
# '-------------------------------- '
# StreamingTV
# No     4336
# Yes    2707
# Name: count, dtype: int64
# '-------------------------------- '
# StreamingMovies
# No     4311
# Yes    2732
# Name: count, dtype: int64

# %%
fig = make_subplots(rows=2, cols=3, subplot_titles=("PhoneService", "MultipleLines","OnlineSecurity","DeviceProtection","StreamingTV","StreamingMovies"))

fig.add_trace(
    go.Bar(x =['Yes','No'], y= PhoneService , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["PhoneService"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ),row=1, col=1)


fig.add_trace(
     go.Bar(x =['No','Yes'], y= MultipleLines, marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["MultipleLines"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=1, col=2
     )


fig.add_trace(
     go.Bar(x =['No','Yes'], y= OnlineSecurity , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["OnlineSecurity"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=1, col=3
     )

fig.add_trace(
     go.Bar(x =['No','Yes'], y= DeviceProtection , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["DeviceProtection"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=2, col=1
     )


fig.add_trace(
     go.Bar(x =['No','Yes'], y= StreamingTV , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["StreamingTV"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=2, col=2
     )


fig.add_trace(
     go.Bar(x =['No','Yes'], y= StreamingMovies , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["StreamingMovies"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=2, col=3
     )


fig.update_yaxes(visible=False, showticklabels=False)
#fig.update_yaxes(title_font=dict(size=18, family='Courier', color='crimson'))
fig.update_layout(height=1000, width=1200,title_text=" ",template='plotly_white',showlegend = False, )

# fig = go.Figure(data=data,layout=configuracoes_layout, layout_yaxis = {'title': ' ',
#                          'visible': False,
#                        'showticklabels': False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# InternetService	 Contract	PaperlessBilling	PaymentMethod

# %%
display("Total")
display(df_clean["InternetService"].value_counts())
display('------------------------------- ')
display(df_clean["Contract"].value_counts())
display('-------------------------------- ')
display(df_clean["PaperlessBilling"].value_counts())
display('-------------------------------- ')
display(df_clean["PaymentMethod"].value_counts())
display('-------------------------------- ')



InternetService = df_clean["InternetService"].value_counts()
Contract= df_clean["Contract"].value_counts()
PaperlessBilling = df_clean["PaperlessBilling"].value_counts()
PaymentMethod = df_clean["PaymentMethod"].value_counts()
# Out:
# 'Total'
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
# '------------------------------- '
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64
# '-------------------------------- '
# PaperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64
# '-------------------------------- '
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64
# '-------------------------------- '

# %%
fig = make_subplots(rows=2, cols=2, subplot_titles=("InternetService", "Contract","PaperlessBilling","PaymentMethod"))

fig.add_trace(
    go.Bar(x =['Fiber optic','DSL','No'], y= InternetService , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["InternetService"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ),row=1, col=1)


fig.add_trace(
     go.Bar(x =['Month-to-month','Two year','One year'], y= Contract, marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["Contract"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=1, col=2
     )


fig.add_trace(
     go.Bar(x =['Yes','No'], y= PaperlessBilling , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["PaperlessBilling"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=2, col=1
     )

fig.add_trace(
     go.Bar(x =['Electronic check','Mailed check','Bank transfer (automatic)','Credit card (automatic)'], y= PaymentMethod , marker = {'color': '#0068B5',
                         'line': {'color': '#334',
                                  'width': 0.7}
                        }, name='Churn' ,text = df_clean["PaymentMethod"].value_counts(normalize=True).map("{:.1%}".format),
      textposition='outside',opacity= 0.9 ), row=2, col=2
     )




fig.update_yaxes(visible=False, showticklabels=False)
#fig.update_yaxes(title_font=dict(size=18, family='Courier', color='crimson'))
fig.update_layout(height=1000, width=1200,title_text=" ",template='plotly_white',showlegend = False, )

# fig = go.Figure(data=data,layout=configuracoes_layout, layout_yaxis = {'title': ' ',
#                          'visible': False,
#                        'showticklabels': False})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure(data=[go.Histogram(x=df_clean['tenure'], marker_color = '#0068B5', nbinsx=150)])

# Layout mit Titleposition
fig.update_layout(height=800, width=1000,title_text="Customer vs Months",template='plotly_white',showlegend = False,title_x=0.5 )
fig.update_yaxes(visible=True, showticklabels=True, title='customer')
fig.update_xaxes(visible=True, showticklabels=True, title='Months')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
